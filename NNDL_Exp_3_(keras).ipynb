# %% [markdown]
# <a href="https://colab.research.google.com/github/RishavRajSharma/NNDL-Lab/blob/main/NNDL_Exp_3_(keras).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
np.random.seed(0)

# Generate dummy transaction data
X = np.random.rand(1000, 6)     # 6 transaction features
y = (np.sum(X, axis=1) > 3).astype(int)  # Fraud (1) / Normal (0)

# Train-test split
X_train, X_test = X[:800], X[800:]
y_train, y_test = y[:800], y[800:]

# %%
model = Sequential()

model.add(Dense(16, activation='relu', input_shape=(6,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5229 - loss: 0.6792 - val_accuracy: 0.5188 - val_loss: 0.6861
# Epoch 2/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5688 - loss: 0.6628 - val_accuracy: 0.5250 - val_loss: 0.6773
# Epoch 3/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5745 - loss: 0.6619 - val_accuracy: 0.5562 - val_loss: 0.6670
# Epoch 4/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5731 - loss: 0.6532 - val_accuracy: 0.6062 - val_loss: 0.6562
# Epoch 5/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6106 - loss: 0.6371 - val_accuracy: 0.6187 - val_loss: 0.6458
# Epoch 6/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6183 - loss: 0.6237 - val_accuracy: 0.6687 - val_loss: 0.6323
# Epoch 7/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6863 - loss: 0.6041 - val_accuracy: 0.6875 - val_loss: 0.6177
# Epoch 8/30
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9373 - loss: 0.2184
# Test Accuracy: 0.9449999928474426

# %%
sample = np.array([[0.9, 0.8, 0.7, 0.6, 0.9, 0.8]])
prediction = model.predict(sample)

print("Fraud Probability:", prediction[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Fraud Probability: 0.9973293
